# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# alabaster                     0.7.16
# anyio                         4.4.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     2.4.1
# async-lru                     2.0.4
# attrs                         24.2.0
# babel                         2.16.0
# beautifulsoup4                4.12.3
# bleach                        6.1.0
# certifi                       2024.8.30
# cffi                          1.17.1
# charset-normalizer            3.3.2
# colorama                      0.4.6
# comm                          0.2.2
# contourpy                     1.2.1
# cycler                        0.12.1
# debugpy                       1.8.5
# decorator                     5.1.1
# defusedxml                    0.7.1
# docutils                      0.20.1
# executing                     2.1.0
# fastjsonschema                2.20.0
# fonttools                     4.53.1
# fqdn                          1.5.1
# h11                           0.14.0
# httpcore                      1.0.5
# httpx                         0.27.2
# idna                          3.8
# imagesize                     1.4.1
# importlib_metadata            8.1.0
# iniconfig                     2.0.0
# ipykernel                     6.29.5
# ipython                       8.27.0
# isoduration                   20.11.0
# jaraco.classes                3.4.0
# jaraco.context                5.3.0
# jaraco.functools              4.0.1
# jedi                          0.19.1
# Jinja2                        3.1.4
# json5                         0.9.25
# jsonpointer                   3.0.0
# jsonschema                    4.23.0
# jsonschema-specifications     2023.12.1
# jupyter_client                8.6.2
# jupyter_core                  5.7.2
# jupyter-events                0.10.0
# jupyter-lsp                   2.2.5
# jupyter_server                2.14.2
# jupyter_server_terminals      0.5.3
# jupyterlab                    4.2.5
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.27.3
# keyring                       25.2.1
# kiwisolver                    1.4.5
# markdown-it-py                3.0.0
# MarkupSafe                    2.1.5
# matplotlib                    3.9.1
# matplotlib-inline             0.1.7
# mdurl                         0.1.2
# mistune                       3.0.2
# more-itertools                10.3.0
# nbclient                      0.10.0
# nbconvert                     7.16.4
# nbformat                      5.10.4
# nest-asyncio                  1.6.0
# nh3                           0.2.18
# notebook_shim                 0.2.4
# numpy                         2.0.1
# openmeteopy                   0.1.0
# overrides                     7.7.0
# packaging                     24.1
# pandas                        2.2.2
# pandocfilters                 1.5.1
# parso                         0.8.4
# pillow                        10.4.0
# pip                           24.2
# pkginfo                       1.10.0
# platformdirs                  4.3.2
# pluggy                        1.5.0
# prometheus_client             0.20.0
# prompt_toolkit                3.0.47
# psutil                        6.0.0
# pure_eval                     0.2.3
# pyarrow                       17.0.0
# pycparser                     2.22
# Pygments                      2.18.0
# pyparsing                     3.1.2
# pytest                        8.3.1
# python-dateutil               2.9.0.post0
# python-json-logger            2.0.7
# pytz                          2024.1
# pywin32                       306
# pywin32-ctypes                0.2.2
# pywinpty                      2.0.13
# PyYAML                        6.0.2
# pyzmq                         26.2.0
# readme_renderer               43.0
# referencing                   0.35.1
# requests                      2.32.3
# requests-toolbelt             1.0.0
# rfc3339-validator             0.1.4
# rfc3986                       2.0.0
# rfc3986-validator             0.1.1
# rich                          13.7.1
# rpds-py                       0.20.0
# Send2Trash                    1.8.3
# setuptools                    74.1.2
# six                           1.16.0
# sniffio                       1.3.1
# snowballstemmer               2.2.0
# soupsieve                     2.6
# Sphinx                        7.4.7
# sphinx-rtd-theme              2.0.0
# sphinxcontrib-applehelp       1.0.8
# sphinxcontrib-devhelp         1.0.6
# sphinxcontrib-htmlhelp        2.0.6
# sphinxcontrib-jquery          4.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.8
# sphinxcontrib-serializinghtml 1.1.10
# stack-data                    0.6.3
# terminado                     0.18.1
# tinycss2                      1.3.0
# tornado                       6.4.1
# traitlets                     5.14.3
# twine                         5.1.1
# types-python-dateutil         2.9.0.20240906
# tzdata                        2024.1
# uri-template                  1.3.0
# urllib3                       2.2.3
# wcwidth                       0.2.13
# webcolors                     24.8.0
# webencodings                  0.5.1
# websocket-client              1.8.0
# wheel                         0.43.0
# zipp                          3.19.2

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.3 MB/s eta 0:00:00
# Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl (273 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.9.1 regex-2024.9.11 tqdm-4.66.5

# %%
# import the library
import nltk

# you need this only once: it is to download the 'punkt' package, which includes a pre-trained tokenizer
nltk.download('punkt_tab') 

sentence = "This is an example sentence. It shows how tokenization works."

# Tokenizing the sentence
tokens = nltk.word_tokenize(sentence)

print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mnoelte\AppData\Roaming\nltk_data...
# ['This', 'is', 'an', 'example', 'sentence', '.', 'It', 'shows', 'how', 'tokenization', 'works', '.']
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
# !pip install python-Levenshtein numpy matplotlib seaborn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (3.9.1)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (2.2.2)
# Collecting Levenshtein==0.26.0 (from python-Levenshtein)
#   Downloading levenshtein-0.26.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.26.0->python-Levenshtein)
#   Downloading rapidfuzz-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mnoelte\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading python_Levenshtein-0.26.0-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.0-cp312-cp312-win_amd64.whl (98 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading rapidfuzz-3.10.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, seaborn, python-Levenshtein
# Successfully installed Levenshtein-0.26.0 python-Levenshtein-0.26.0 rapidfuzz-3.10.0 seaborn-0.13.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from Levenshtein import distance as levenshtein_distance

tokens = ['This', 'is', 'an', 'example', 'sentence', '.', 'It', 'shows', 'how', 'tokenization', 'works', '.']

# calculate the distance matrix
dist_matrix = np.zeros((len(tokens), len(tokens)))

for i in range(len(tokens)):
    for j in range(len(tokens)):
        dist_matrix[i,j] = levenshtein_distance(tokens[i], tokens[j])

# create a dataframe from the distance matrix
df = pd.DataFrame(dist_matrix, index=tokens, columns=tokens)

# plot the distance matrix
plt.figure(figsize = (10,7))
sns.heatmap(df, annot=True, cmap='viridis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from Levenshtein import distance as levenshtein_distance

# misspelling test: "'tokenIzation', 'exanple'"
tokens = ['This', 'is', 'an', 'example', 'sentence', '.', 'It', 'shows', 'how', 'tokenization', 'works', '.', 'tokenIzation', 'exanple']

# calculate the distance matrix
dist_matrix = np.zeros((len(tokens), len(tokens)))

for i in range(len(tokens)):
    for j in range(len(tokens)):
        # "/ max(len(tokens[i]), len(tokens[j]))" normalises by the length of the longest token
        dist_matrix[i,j] = levenshtein_distance(tokens[i], tokens[j]) / max(len(tokens[i]), len(tokens[j]))

# create a dataframe from the distance matrix
df = pd.DataFrame(dist_matrix, index=tokens, columns=tokens)

# plot the distance matrix
plt.figure(figsize = (10,7))
sns.heatmap(df, annot=True, cmap='viridis')
plt.show()
